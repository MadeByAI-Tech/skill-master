# %% [markdown]
# # Schema for `JobPostExtracted` table
# | Job_Post_Extracted   |
# |-------------|
# | id          |
# | job_title   |
# | location    |
# | job_function (sector) |
# | skills      |
# | CWFs        |
# | version_id  |

# %% [markdown]
# ## Load `dev.env`

# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path="../.envfiles/dev.env")
import os

BQ_PROJECT = os.environ["BQ_PROJECT"]
BQ_DATASET = os.environ["BQ_DATASET"]

# %% [markdown]
# ## Run pipeline `JobPostExtracted.py`

# %%
from pipeline.processing_job import job_post_extraction_pipeline

job_post_extraction_pipeline()
# Out:
# ──────────────────────────────
#      Pipeline started
# ──────────────────────────────
# === RUNNING: get_client()...
# === DONE:    get_client()
# === RUNNING: get_dataset()...
# Dataset already exists
# === DONE:    get_dataset()
# === Reading rows from JobPosts table...
# === Row fetch completed. Total rows = 100
# === Processing `5` rows for testing
#
# ──────────────────────────────
#      Extraction started
# ──────────────────────────────
# - Processing row 1/5, job_id=86122800
#   Row 1 extraction completed
# - Processing row 2/5, job_id=86131280
#   Row 2 extraction completed
# - Processing row 3/5, job_id=86119281
#   Row 3 extraction completed
# - Processing row 4/5, job_id=85424062
#   Row 4 extraction completed
# - Processing row 5/5, job_id=86119406
#   Row 5 extraction completed
# === Inserting processed rows into JobPostExtracted...
# === Data inserted successfully to JobPostExtracted table
# '200 OK'

# %% [markdown]
# ## Show schema for `JobPostExtracted` table

# %%
import json
from db import get_client, get_dataset

client = get_client()
dataset = get_dataset()

table_id = f"{client.project}.{dataset.dataset_id}.JobPostExtracted"
table = client.get_table(table_id)

schema_json = [
    {"name": f.name, "type": f.field_type, "mode": f.mode}
    for f in table.schema
]

count_query = f"""
SELECT COUNT(*) AS total
FROM `{table_id}`
"""

rows = list(client.query_and_wait(count_query))
row_count = rows[0]["total"]

print(json.dumps({
    "schema": schema_json,
    "total_rows": row_count
}, indent=2))
# Out:
# Dataset already exists
# {
#   "schema": [
#     {
#       "name": "job_id",
#       "type": "INTEGER",
#       "mode": "REQUIRED"
#     },
#     {
#       "name": "job_title",
#       "type": "STRING",
#       "mode": "REQUIRED"
#     },
#     {
#       "name": "location",
#       "type": "STRING",
#       "mode": "REQUIRED"
#     },
#     {
#       "name": "job_function",
#       "type": "STRING",
#       "mode": "REQUIRED"
#     },
#     {
#       "name": "description",
#       "type": "STRING",
#       "mode": "REQUIRED"
#     },
#     {
#       "name": "skills",
#       "type": "JSON",
#       "mode": "REQUIRED"
#     },
#     {
#       "name": "cwf_items",
#       "type": "JSON",
#       "mode": "REQUIRED"
#     }
#   ],
#   "total_rows": 5
# }

# %% [markdown]
# ## Count rows inside `JobPostExtracted` table

# %%
from db import get_client, get_dataset

client = get_client()
dataset = get_dataset()

query = f"""
SELECT COUNT(*) as total
FROM `{client.project}.{dataset.dataset_id}.JobPostExtracted`
"""

rows = list(client.query_and_wait(query))
print(f"=== Total rows: {rows[0]['total']}")
# Out:
# Dataset already exists
# === Total rows: 5

# %% [markdown]
# ## Show data inside `JobPostExtracted` table

# %%
import json

query = f"""
SELECT *
FROM `{client.project}.{dataset.dataset_id}.JobPostExtracted`
LIMIT 50
"""

rows = list(client.query_and_wait(query))

if not rows:
    print("No data in `JobPostExtracted` table")
else:
    for i, r in enumerate(rows, start=1):
        print("\n" + "="*80)
        print(f"    ROW {i}  |  JOB ID: {r['job_id']}  |  TITLE: {r['job_title']}")
        print("="*80)

        print(json.dumps(dict(r), indent=2, ensure_ascii=False))
# Out:
# ================================================================================
#     ROW 1  |  JOB ID: 86122800  |  TITLE: Management Trainee Account
# ================================================================================
# {
#   "job_id": 86122800,
#   "job_title": "Management Trainee Account",
#   "location": "Ang Thong",
#   "job_function": "Accounting",
#   "description": "Job Description:\n\nFixed Assets Accounting for all 3 Units\n\nFixed asset Physical verification\n\nComplete physical verification at plant.\n\nUpdating of cycle count data to SAP.\n\nReconcile cycle count with SAP after verification.\n\nEmployee Payroll for local & expats\n\nWHT for personal taxes\n\nWHT working preparation reconciling with GL's & advising monthly payment.\n\nChecking and return filing on monthly and yearly basis (PND1 etc.)\n\nAudit Requirement\n\nProviding necessary documents related to Payroll such as register, headcount and other relevant details for quarterly statutory audit.\n\nPreparation of Director Remuneration and any other payroll, capex and WHT tax details required for quarterly audit closing.\n\nAny other details if required.\n\nQualifications:\n\nBachelor's degree in Account or Finance.\n\nLocal candidate preferred.\n\nExperience more than 3 years.\n\nGood knowledge for SAP skill.        \n\nGood Excel skills.\n\nAble to communicate in English and Thai.\n\nGood in problem solving and analytical thinking and.   \n\nBenefits total more than 40 items:\n\nBonus \n\nProvident Fund 5%\n\nLife Insurance and Medical Claimed included family.\n\nSpecial Leave with pay i.e. funeral, marriage\n\nSpecial Allowance for Marriage, Cremation (Spouse, Children, Parents)\n\nActivities Budget (New Year, Farewell Party, Department Party, Sport Day)\n\nOthers such as Diligent Award, Quarterly Team/Individual Performance Reward.",
#   "skills": [
#     {
#       "evidence": "Good knowledge for SAP skill.",
#       "skill_title": "SAP",
#       "skill_type": "TSC"
#     },
#     {
#       "skill_title": "Excel",
#       "skill_type": "TSC",
#       "evidence": "Good Excel skills."
#     },
#     {
#       "evidence": "Good in problem solving and analytical thinking.",
#       "skill_title": "Problem Solving",
#       "skill_type": "TSC"
#     }
#   ],
#   "cwf_items": [
#     {
#       "cwf_topic": "Fixed Assets Accounting",
#       "key_task": "Fixed asset Physical verification"
#     },
#     {
#       "cwf_topic": "Cycle Count Management",
#       "key_task": "Updating of cycle count data to SAP."
#     },
#     {
#       "cwf_topic": "Payroll Management",
#       "key_task": "Employee Payroll for local & expats"
#     },
#     {
#       "cwf_topic": "Tax Preparation",
#       "key_task": "WHT for personal taxes"
#     },
#     {
#       "key_task": "Providing necessary documents related to Payroll for quarterly statutory audit.",
#       "cwf_topic": "Audit Support"
#     }
#   ]
# }
#
# ================================================================================
#     ROW 2  |  JOB ID: 86131280  |  TITLE: Consolidation (Assistant Manager - Manager)
# ================================================================================
# {
#   "job_id": 86131280,
#   "job_title": "Consolidation (Assistant Manager - Manager)",
#   "location": "Bang Kapi, Bangkok",
#   "job_function": "Accounting",
#   "description": "Location: Krungthep Kreetha\n\nWebsite: https://www.bgrimmpower.com/en/home\n\nJob Scopes:\n\nPrepare annual and quarterly statutory consolidated financial statements.\n\nPrepare monthly consolidated financial information for external and internal stakeholders.\n\nProvide overall analysis on consolidated financial statements.\n\nSupport financial information for MD&A report, One report, DJSI report, Budgeting and others.\n\nProvide timely financial consolidation insights to support decision-making.\n\nCoordinate with tax teams to incorporate Pillar 2 Global Minimum Tax adjustments in the consolidation process.\n\nSupport ESG-related financial disclosures in line with global sustainability reporting standards.\n\nSpecial project: e.g. Implement new accounting standards, restructuring, M&A due diligence.\n\nProvide guidance to overseas accounting teams to align with group consolidation policies.\n\nCoordinate with external auditors and various departments both domestic and international.\n\nOther tasks as assigned.\n\nQualifications:\n\nBachelor’s Degree in Accounting.\n\nMinimum 5 years of relevant experience, including at least 3 years of Audit firm (Listed company experience).\n\nStrong knowledge of accounting standards (TFRS, IFRS) and consolidation technical knowledge with multinational working environment or collaborating with overseas teams.\n\nStrong analytical and managerial skills.\n\nProactive, with the ability to manage multiple priorities under tight deadlines.\n\nAbility to work independently and collaboratively within a team.\n\nGood command of English with Thai speaking.",
#   "skills": [
#     {
#       "skill_type": "TSC",
#       "evidence": "Provide overall analysis on consolidated financial statements.",
#       "skill_title": "Financial Analysis"
#     },
#     {
#       "skill_title": "Consolidation",
#       "skill_type": "TSC",
#       "evidence": "Prepare annual and quarterly statutory consolidated financial statements."
#     },
#     {
#       "skill_title": "Accounting Standards",
#       "skill_type": "TSC",
#       "evidence": "Strong knowledge of accounting standards (TFRS, IFRS) and consolidation technical knowledge."
#     },
#     {
#       "evidence": "Special project: e.g. Implement new accounting standards, restructuring, M&A due diligence.",
#       "skill_title": "Project Management",
#       "skill_type": "TSC"
#     }
#   ],
#   "cwf_items": [
#     {
#       "cwf_topic": "Financial Reporting",
#       "key_task": "Prepare monthly consolidated financial information for external and internal stakeholders."
#     },
#     {
#       "cwf_topic": "Financial Reporting",
#       "key_task": "Support financial information for MD&A report, One report, DJSI report, Budgeting and others."
#     },
#     {
#       "cwf_topic": "Decision Support",
#       "key_task": "Provide timely financial consolidation insights to support decision-making."
#     },
#     {
#       "cwf_topic": "Tax Coordination",
#       "key_task": "Coordinate with tax teams to incorporate Pillar 2 Global Minimum Tax adjustments in the consolidation process."
#     },
#     {
#       "cwf_topic": "ESG Reporting",
#       "key_task": "Support ESG-related financial disclosures in line with global sustainability reporting standards."
#     },
#     {
#       "cwf_topic": "Team Guidance",
#       "key_task": "Provide guidance to overseas accounting teams to align with group consolidation policies."
#     },
#     {
#       "key_task": "Coordinate with external auditors and various departments both domestic and international.",
#       "cwf_topic": "Audit Coordination"
#     }
#   ]
# }
#
# ================================================================================
#     ROW 3  |  JOB ID: 86119281  |  TITLE: Assistant Accounting Manager
# ================================================================================
# {
#   "job_id": 86119281,
#   "job_title": "Assistant Accounting Manager",
#   "location": "Bang Kapi, Bangkok",
#   "job_function": "Accounting",
#   "description": "1.ควบคุม ดูแล และบริหารงานด้านบัญชีทั้งหมดของบริษัท ให้เป็นไปตามมาตรฐานบัญชีที่รับรองทั่วไป และข้อกำหนดของกรมสรรพากร\n\n2.ตรวจสอบงบการเงิน งบดุล และรายงานทางการเงินต่าง ๆ ให้ถูกต้องครบถ้วน\n\n3.วางแผนและควบคุมงบประมาณรายปี รวมถึงตรวจสอบค่าใช้จ่ายของแต่ละแผนก\n\n4.ประสานงานกับผู้สอบบัญชีภายนอก และหน่วยงานที่เกี่ยวข้อง\n\n5.รายงานข้อมูลทางบัญชีให้ผู้บริหารเพื่อใช้ในการตัดสินใจ\n\n6.งานอื่น ๆ ตามที่ได้รับมอบหมายจากผู้บริหาร\n\nคุณสมบัติ\n\n1. วุฒิการศึกษาระดับปริญญาตรีขึ้นไป สาขาบัญชี (ถ้ามีใบอนุญาตเป็นผู้ทำบัญชี หรือ CPA จะพิจารณาเป็นพิเศษ)\n\n2. มีประสบการณ์ในงานบัญชีอย่างน้อย 5 ปี และมีประสบการณ์ในตำแหน่งบริหารไม่น้อยกว่า 2 ปี\n\n3.มีความรู้ด้านมาตรฐานการบัญชี, กฎหมายภาษี และกฎหมายธุรกิจ\n\n4.สามารถใช้โปรแกรม MS Excel และโปรแกรมบัญชีทั่วไปได้ดี\n\n5.มีภาวะผู้นำสูง วางแผนงาน บริหารทีม ดูแลการทำงาน พัฒนาศักยภาพของพนักงานในทีม\n\n6.มีความรับผิดชอบสูง ตรงต่อเวลา และทำงานภายใต้แรงกดดันได้",
#   "skills": [
#     {
#       "skill_title": "Financial Reporting",
#       "skill_type": "TSC",
#       "evidence": "ตรวจสอบงบการเงิน งบดุล และรายงานทางการเงินต่าง ๆ ให้ถูกต้องครบถ้วน"
#     },
#     {
#       "skill_title": "Budget Management",
#       "skill_type": "TSC",
#       "evidence": "วางแผนและควบคุมงบประมาณรายปี รวมถึงตรวจสอบค่าใช้จ่ายของแต่ละแผนก"
#     },
#     {
#       "skill_title": "Accounting Standards",
#       "skill_type": "TSC",
#       "evidence": "ให้เป็นไปตามมาตรฐานบัญชีที่รับรองทั่วไป"
#     },
#     {
#       "skill_title": "Leadership",
#       "skill_type": "TSC",
#       "evidence": "มีภาวะผู้นำสูง วางแผนงาน บริหารทีม ดูแลการทำงาน"
#     },
#     {
#       "evidence": "สามารถใช้โปรแกรม MS Excel และโปรแกรมบัญชีทั่วไปได้ดี",
#       "skill_title": "Excel",
#       "skill_type": "TSC"
#     }
#   ],
#   "cwf_items": [
#     {
#       "cwf_topic": "Accounting Management",
#       "key_task": "ควบคุม ดูแล และบริหารงานด้านบัญชีทั้งหมดของบริษัท"
#     },
#     {
#       "cwf_topic": "Financial Reporting",
#       "key_task": "ตรวจสอบงบการเงิน งบดุล และรายงานทางการเงินต่าง ๆ"
#     },
#     {
#       "cwf_topic": "Budget Management",
#       "key_task": "วางแผนและควบคุมงบประมาณรายปี"
#     },
#     {
#       "cwf_topic": "Coordination",
#       "key_task": "ประสานงานกับผู้สอบบัญชีภายนอก และหน่วยงานที่เกี่ยวข้อง"
#     },
#     {
#       "key_task": "รายงานข้อมูลทางบัญชีให้ผู้บริหารเพื่อใช้ในการตัดสินใจ",
#       "cwf_topic": "Reporting"
#     },
#     {
#       "cwf_topic": "Other Duties",
#       "key_task": "งานอื่น ๆ ตามที่ได้รับมอบหมายจากผู้บริหาร"
#     }
#   ]
# }
#
# ================================================================================
#     ROW 4  |  JOB ID: 85424062  |  TITLE: Accounting Assistant Manager
# ================================================================================
# {
#   "job_id": 85424062,
#   "job_title": "Accounting Assistant Manager",
#   "location": "Bang Khen, Bangkok",
#   "job_function": "Accounting",
#   "description": "ตำแหน่ง: Accounting Assistant Manager\n\nสำหรับตำแหน่ง Accounting Assistant Manager ที่ Able Medical Company Limited ในบางเขน กรุงเทพฯ คุณจะมีบทบาทสำคัญในการรักษาระบบการเงินของบริษัทให้ดำเนินไปอย่างราบรื่นและมีประสิทธิภาพ โดยจะทำงานร่วมกับทีมบัญชีและการเงินในการประมวลผลข้อมูลทางการเงิน จัดทำรายงานการเงิน และสนับสนุนกลยุทธ์ทางการเงินของบริษัท\n\nหน้าที่หลัก:\n\nวางแผนระบบบัญชีการเงิน: วางโครงสร้างและควบคุมระบบบัญชีให้รองรับมาตรฐาน IFRS/TFRS และข้อกำหนดกรมสรรพากร พร้อมทั้งติดตามเทคโนโลยีใหม่ๆ เช่น ระบบ ERP เพื่อเชื่อมโยงข้อมูลบัญชีทุกฝ่ายอย่างมีประสิทธิภาพ\n\nตรวจสอบรายการบัญชี: ตรวจสอบความถูกต้องของรายการเดินบัญชี รายรับ–รายจ่าย และเอกสารประกอบ ให้ครบถ้วนสมบูรณ์ตามมาตรฐานบัญชีและหลักฐานอ้างอิง\n\nจัดทำงบการเงิน: ควบคุมดูแลการจัดทำงบการเงินสำคัญ เช่น งบดุล งบกำไรขาดทุน งบกระแสเงินสด และรายงานทางการเงินอื่นๆ ทั้งรายเดือน/ไตรมาส/ประจำปี ให้ถูกต้องและตรงเวลาth.jobsdb.comrgf-hragent.asia\n\nจัดการภาษี: วางแผนและควบคุมภาระภาษีต่างๆ ทั้งภาษีมูลค่าเพิ่ม ภาษีหัก ณ ที่จ่าย และภาษีนิติบุคคล ให้สอดคล้องกับกฎหมายภาษีปัจจุบัน รวมถึงจัดทำและยื่นแบบภาษีให้ถูกต้องทันกำหนด\n\nประสานงานภายนอก: ประสานกับผู้สอบบัญชีภายนอก กรมสรรพากร และหน่วยงานอื่นที่เกี่ยวข้องในการตรวจสอบบัญชีและภาษี เพื่อให้การรายงานทางการเงินถูกต้องครบถ้วนตามข้อกำหนดrgf-hragent.asiath.jobsdb.com\n\nบริหารทีมบัญชี: ควบคุมและพัฒนาทีมบัญชี (เช่น ผู้ช่วยผู้จัดการบัญชี พนักงานทั่วไป) โดยจัดสรรงาน ฝึกอบรม และตรวจสอบการบันทึกบัญชีในระบบ ERP เพื่อให้การทำงานราบรื่นและแม่นยำrgf-hragent.asia1stcraft.com\n\nบัญชีต้นทุน: สนับสนุนการจัดทำบัญชีต้นทุนสินค้า รวมถึงการวิเคราะห์ต้นทุนที่เกี่ยวข้อง โดยเฉพาะในอุตสาหกรรมยาและเวชภัณฑ์ ซึ่งต้องคุมต้นทุนการผลิต ต้นทุนวัสดุ และค่าใช้จ่ายการจัดจำหน่ายเพื่อช่วยในการตั้งราคาขายและควบคุมค่าใช้จ่ายplanettogether.com1stcraft.com\n\nพัฒนาระบบตาม GMP/GDP: พัฒนาระบบงานบัญชีให้สอดคล้องกับมาตรฐาน GMP (Good Manufacturing Practices) และ GDP (Good Distribution Practices) ของอุตสาหกรรมยา เช่น การจัดทำรายงานที่สามารถตรวจสอบย้อนกลับได้ชัดเจน เพื่อรับรองคุณภาพและความถูกต้องในการตรวจสอบจากหน่วยงานกำกับดูแล\n\nมีความรู้เกี่ยวกับสิทธิประโยชน์ BOI : ประสบการณ์บัญชีในบริษัทภายใต้บัตรส่งเสริม BOI, ความเข้าใจสิทธิประโยชน์ทางภาษี BOI (ภาษีเงินได้นิติบุคคล, ภาษีขาเข้า) และทักษะในการจัดทำเอกสารรายงาน BOI (เช่น ตส.310, ภงด.50)\n\nทักษะ คุณสมบัติ และประสบการณ์:\n\nปริญญาตรีด้านการบัญชี หรือสาขาที่เกี่ยวข้อง\n\nมีประสบการณ์ในงานด้านบัญชีการเงิน หรือที่เกี่ยวข้องกับการเงินอย่างน้อย 5 ปี\n\nมีความเข้าใจอย่างลึกซึ้งเกี่ยวกับมาตรฐานการบัญชีและกฎระเบียบที่เกี่ยวข้อง\n\nมีทักษะการวิเคราะห์และแก้ไขปัญหาที่ดี สามารถจัดการงานได้หลากหลายและภายในกรอบเวลาที่กำหนด\n\nมีทักษะการสื่อสารและการนำเสนอที่ดี สามารถทำงานร่วมกับทีมบัญชีและผู้บริหารระดับสูงได้เป็นอย่างดี\n\nสมัครงานกับ Able Medical Company Limited วันนี้!",
#   "skills": [
#     {
#       "skill_type": "TSC",
#       "evidence": "Prepare financial reports and support the company's financial strategy.",
#       "skill_title": "Financial Reporting"
#     },
#     {
#       "skill_title": "Tax Management",
#       "skill_type": "TSC",
#       "evidence": "Plan and control various tax burdens in accordance with current tax laws."
#     },
#     {
#       "skill_title": "Team Management",
#       "skill_type": "TSC",
#       "evidence": "Manage and develop the accounting team by allocating tasks and training."
#     },
#     {
#       "skill_title": "Accounting Standards",
#       "skill_type": "TSC",
#       "evidence": "Ensure compliance with IFRS/TFRS and tax regulations."
#     },
#     {
#       "skill_title": "Cost Accounting",
#       "skill_type": "TSC",
#       "evidence": "Support the preparation of product cost accounting and analyze related costs."
#     }
#   ],
#   "cwf_items": [
#     {
#       "cwf_topic": "Accounting System Planning",
#       "key_task": "Plan the accounting system to comply with IFRS/TFRS standards."
#     },
#     {
#       "cwf_topic": "Account Verification",
#       "key_task": "Verify the accuracy of account transactions and supporting documents."
#     },
#     {
#       "cwf_topic": "Financial Statement Preparation",
#       "key_task": "Oversee the preparation of key financial statements."
#     },
#     {
#       "cwf_topic": "External Coordination",
#       "key_task": "Coordinate with external auditors and tax authorities."
#     },
#     {
#       "cwf_topic": "GMP/GDP Compliance",
#       "key_task": "Develop accounting systems in accordance with GMP and GDP standards."
#     },
#     {
#       "cwf_topic": "BOI Knowledge",
#       "key_task": "Understand BOI benefits and prepare related documentation."
#     }
#   ]
# }
#
# ================================================================================
#     ROW 5  |  JOB ID: 86119406  |  TITLE: Manager , Accounting - AP & Tax (Property) - Bangna
# ================================================================================
# {
#   "job_id": 86119406,
#   "job_title": "Manager , Accounting - AP & Tax (Property) - Bangna",
#   "location": "Bang Na, Bangkok",
#   "job_function": "Accounting",
#   "description": "Key Responsibility:\n\nControl AP & Payment schedule\n\nValidate accuracy of document payment\n\nReview contract to ensure appropriateness\n\nLease management\n\nRPT reconciliation re AP\n\nEnsure compliance with local, state and international tax law\n\nPrepare tax returns or work with external firms to ensure timely filings\n\nStay current on regulatory changes and accounting standards\n\nResponsible for all tax documents WHT, VAT, Corp Tax\n\nTax report & Reconciliation\n\nDeferred tax transaction\n\nDeal with RD and CPAXT Tax\n\n\nQualifications:\n\nBachelor’s degree in Accounting, Finance, or a related field\n\nAt least 6 years of experience in Finance & Accounting is a MUST\n\nProficiency in accounting ERP software (e.g. Oracle)\n\nStrong understanding of accounting principles and tax regulations\n\nExperience in Property, Real Estate is a plus\n\nGood command of spoken and written English and strong MS Excel/database skills\n\nProven track record of working cross-functionally\n\nBe self-motivated, independent, analytical, and adaptable to change\n\nAbility to manage complex planning and process improvement\n\nNegotiation & Communication skills\n\nDecision-making & Problem solving skills\n\nAttention to detail, analytical thinking, and time management\n\nGood communication and interpersonal skills\n\n\n\n\nCP AXTRA | Lotus's\nCP AXTRA Public Company Limited.\nNawamin Office: Buengkum, Bangkok 10230, Thailand\n\n“By applying for this position, you consent to the collection, use and disclosure of your personal data to us, our recruitment firms and all relevant third parties for the purpose of processing your application for this job position (or any other suitable positions within Lotus's and its subsidiaries, if any). You understand and acknowledge that your personal data will be processed in accordance with the law and our policy",
#   "skills": [
#     {
#       "skill_title": "Accounting ERP Software",
#       "skill_type": "TSC",
#       "evidence": "Proficiency in accounting ERP software (e.g. Oracle)"
#     },
#     {
#       "skill_title": "Tax Compliance",
#       "skill_type": "TSC",
#       "evidence": "Ensure compliance with local, state and international tax law"
#     },
#     {
#       "skill_title": "Tax Reporting",
#       "skill_type": "TSC",
#       "evidence": "Prepare tax returns or work with external firms to ensure timely filings"
#     },
#     {
#       "skill_title": "Analytical Thinking",
#       "skill_type": "GSC",
#       "evidence": "Attention to detail, analytical thinking, and time management"
#     }
#   ],
#   "cwf_items": [
#     {
#       "cwf_topic": "AP Processing",
#       "key_task": "Control AP & Payment schedule"
#     },
#     {
#       "cwf_topic": "Document Validation",
#       "key_task": "Validate accuracy of document payment"
#     },
#     {
#       "cwf_topic": "Contract Review",
#       "key_task": "Review contract to ensure appropriateness"
#     },
#     {
#       "cwf_topic": "Lease Management",
#       "key_task": "Lease management"
#     },
#     {
#       "cwf_topic": "Tax Management",
#       "key_task": "Responsible for all tax documents WHT, VAT, Corp Tax"
#     },
#     {
#       "cwf_topic": "Tax Reconciliation",
#       "key_task": "Tax report & Reconciliation"
#     },
#     {
#       "cwf_topic": "Regulatory Compliance",
#       "key_task": "Stay current on regulatory changes and accounting standards"
#     }
#   ]
# }

# %% [markdown]
# ## Truncate `JobPostExtracted` table

# %%
from db import get_client, get_dataset

client = get_client()
dataset = get_dataset()

table = f"{client.project}.{dataset.dataset_id}.JobPostExtracted"
print("=== Target table:", table)

query = f"""
DELETE FROM `{client.project}.{dataset.dataset_id}.JobPostExtracted`
WHERE TRUE
"""

client.query(query).result()
print("=== `JobPostExtracted` truncated successfully")

# COUNT
count_query = f"""
SELECT COUNT(*) AS total
FROM `{client.project}.{dataset.dataset_id}.JobPostExtracted`
"""

rows = list(client.query(count_query))
print(f"=== Total rows: {rows[0]['total']}")

# %% [markdown]
# ---

# %% [markdown]
# ## Test `src/models/JobPostExtracted.py`

# %% [markdown]
# ### Delete table

# %%
from dotenv import load_dotenv
load_dotenv("../.envfiles/dev.env")

from models.JobPostExtracted import JobPostExtracted
from db import get_client, get_dataset

client = get_client()
dataset = get_dataset()
dataset_id = dataset.dataset_id

print("=== Target dataset:", dataset_id)
print("=== Project:", client.project)

# Delete `JobPostExtracted` table
print("\n=== Deleting `JobPostExtracted` table...")
JobPostExtracted.delete_table(dataset_id, client)

print("\n=== `JobPostExtracted` table deletd successfully.")
# Out:
# Dataset already exists
# === Target dataset: dev
# === Project: skill-master
#
# === Deleting `JobPostExtracted` table...
# Deleted ` skill-master.dev.JobPostExtracted` table
#
# === `JobPostExtracted` table deletd successfully.

# %% [markdown]
# ### Create table

# %%
from dotenv import load_dotenv
load_dotenv("../.envfiles/dev.env")

from models.JobPostExtracted import JobPostExtracted
from db import get_client, get_dataset

client = get_client()
dataset = get_dataset()
dataset_id = dataset.dataset_id

print("=== Target dataset:", dataset_id)
print("=== Project:", client.project)

# Create `JobPostExtracted` table
print("\n=== Creating `JobPostExtracted` table...")
JobPostExtracted.create_table(dataset_id, client)

print("\n=== `JobPostExtracted` table created successfully.")
# Out:
# Dataset already exists
# === Target dataset: dev
# === Project: skill-master
#
# === Creating `JobPostExtracted` table...
# Created `skill-master.dev.JobPostExtracted` table
#
# === `JobPostExtracted` table created successfully.

# %% [markdown]
# ## Show all tables

# %%
from db import get_client, get_dataset

client = get_client()
dataset = get_dataset()

print("\nBQ_DATASET:", dataset.dataset_id)

tables = list(client.list_tables(dataset.dataset_id))

if not tables:
    print("No tables found.")
else:
    print("Tables:")
    for t in tables:
        print("-", t.table_id)
# Out:
# Dataset already exists
#
# BQ_DATASET: dev
# Tables:
# - people
# - JobPosts
# - JobPostExtracted

# %% [markdown]
# ---
